# %%
import pandas as pd

# Load the dataset 
df = pd.read_csv("Sepsis.csv")

# Calculate the mean values for the columns with missing data for the main variables in predicting sepsis
mean_temp = df['Temp'].mean()
mean_sbp = df['SBP'].mean()
mean_dbp = df['DBP'].mean()
mean_resp = df['Resp'].mean()
mean_o2sat = df['O2Sat'].mean()
mean_map = df['MAP'].mean()
mean_hr = df['HR'].mean()

# Fill in missing values with the corresponding mean values
df['Temp'].fillna(mean_temp, inplace=True)
df['SBP'].fillna(mean_sbp, inplace=True)
df['DBP'].fillna(mean_dbp, inplace=True)
df['Resp'].fillna(mean_resp, inplace=True)
df['O2Sat'].fillna(mean_o2sat, inplace=True)
df['MAP'].fillna(mean_map, inplace=True)
df['HR'].fillna(mean_hr, inplace=True)

# limit to one decimal place to these variables
columns_to_limit = ['SBP', 'DBP', 'Resp', 'O2Sat', 'MAP', 'HR']

# Limit values to one decimal place in specified columns
df[columns_to_limit] = df[columns_to_limit].round(1)

# Save the updated dataset to a new CSV file
df.to_csv("filled_patient_data.csv", index=False)

# %%
#The examination of the variables and columns including mean, median, mode and variable type is below as instructed.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("unique_patient_data.csv")

# Column names
column_names = df.columns.tolist()

# Data types
data_types = df.dtypes

# Description of the columns
column_description = df.describe(include='all')

# Counts and percents unique values
unique_value_counts = df.nunique()
unique_value_percents = (unique_value_counts / len(df)) * 100

# Ranges of values
value_ranges = df.describe().loc[['min', 'max']]

# Output the results
print("Column Names:")
print(column_names)
print("\nData Types:")
print(data_types)
print("\nDescription of the Columns:")
print(column_description)
print("\nCounts of Unique Values:")
print(unique_value_counts)
print("\nPercentage of Unique Values:")
print(unique_value_percents)
print("\nRanges of Values:")
print(value_ranges)
# Out:
# C:\Users\nicho\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\nicho\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\nicho\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# Column Names:
# ['Unnamed: 0', 'Hour', 'HR', 'O2Sat', 'Temp', 'SBP', 'MAP', 'DBP', 'Resp', 'EtCO2', 'BaseExcess', 'HCO3', 'FiO2', 'pH', 'PaCO2', 'SaO2', 'AST', 'BUN', 'Alkalinephos', 'Calcium', 'Chloride', 'Creatinine', 'Bilirubin_direct', 'Glucose', 'Lactate', 'Magnesium', 'Phosphate', 'Potassium', 'Bilirubin_total', 'TroponinI', 'Hct', 'Hgb', 'PTT', 'WBC', 'Fibrinogen', 'Platelets', 'Age', 'Gender', 'Unit1', 'Unit2', 'HospAdmTime', 'ICULOS', 'SepsisLabel', 'Patient_ID']
#
# Data Types:
# Unnamed: 0            int64
# Hour                  int64
# HR                  float64
# O2Sat               float64
# Temp                float64
# SBP                 float64
# MAP                 float64
# DBP                 float64
# Resp                float64
# EtCO2               float64
# BaseExcess          float64
# HCO3                float64
# FiO2                float64
# pH                  float64
# PaCO2               float64
# SaO2                float64
# AST                 float64
# BUN                 float64
# Alkalinephos        float64
# Calcium             float64
# Chloride            float64
# Creatinine          float64
# Bilirubin_direct    float64
# Glucose             float64
# Lactate             float64
# Magnesium           float64
# Phosphate           float64
# Potassium           float64
# Bilirubin_total     float64
# TroponinI           float64
# Hct                 float64
# Hgb                 float64
# PTT                 float64
# WBC                 float64
# Fibrinogen          float64
# Platelets           float64
# Age                 float64
# Gender                int64
# Unit1               float64
# Unit2               float64
# HospAdmTime         float64
# ICULOS                int64
# SepsisLabel           int64
# Patient_ID            int64
# dtype: object
#
# Description of the Columns:
#          Unnamed: 0          Hour            HR         O2Sat          Temp  \
# count  27101.000000  27101.000000  27101.000000  27101.000000  27101.000000
# mean      18.891185     18.891185     84.513977     97.193137     36.993539
# std       17.179201     17.179201     16.138505      2.903537      0.462853
# min        0.000000      0.000000     20.000000     22.000000     30.200000
# 25%        7.000000      7.000000     74.000000     96.000000     37.000000
# 50%       15.000000     15.000000     84.900000     97.200000     37.000000
# 75%       27.000000     27.000000     94.000000     99.000000     37.000000
# max      329.000000    329.000000    167.000000    100.000000     41.800000
#
#                 SBP           MAP           DBP          Resp       EtCO2  \
# count  27101.000000  27101.000000  27101.000000  27101.000000  373.000000
# mean     121.943784     80.379233     62.169444     18.634117   32.869973
# std       20.494403     14.683358     10.183097      4.842662    8.438574
# min       28.000000     20.000000     22.000000      1.000000   10.000000
# 25%      108.000000     71.000000     58.000000     16.000000   28.000000
# 50%      122.400000     80.600000     62.200000     18.800000   33.000000
# 75%      132.000000     87.700000     63.000000     21.000000   38.000000
# max      274.000000    298.000000    166.000000     97.000000   79.000000
#
#        ...  Fibrinogen    Platelets           Age        Gender         Unit1  \
# count  ...  185.000000  1717.000000  27101.000000  27101.000000  15548.000000
# mean   ...  286.275676   199.517472     62.159382      0.572599      0.496527
# std    ...  147.680857   106.817233     16.340117      0.494710      0.500004
# min    ...   59.000000     7.000000     15.000000      0.000000      0.000000
# 25%    ...  183.000000   129.000000     51.800000      0.000000      0.000000
# 50%    ...  246.000000   183.000000     64.000000      1.000000      0.000000
# 75%    ...  350.000000   247.000000     74.900000      1.000000      1.000000
# max    ...  816.000000  1092.000000    100.000000      1.000000      1.000000
#
#               Unit2   HospAdmTime        ICULOS   SepsisLabel     Patient_ID
# count  15548.000000  27100.000000  27101.000000  27101.000000   27101.000000
# mean       0.503473    -50.697649     20.611822      0.031106   35077.379100
# std        0.500004    144.882658     17.495590      0.173607   43572.104286
# min        0.000000  -5366.900000      1.000000      0.000000       1.000000
# 25%        0.000000    -39.200000      9.000000      0.000000    6776.000000
# 50%        1.000000     -4.400000     17.000000      0.000000   13551.000000
# 75%        1.000000      0.000000     29.000000      0.000000   20633.000000
# max        1.000000     24.000000    333.000000      1.000000  119998.000000
#
# [8 rows x 44 columns]
#
# Counts of Unique Values:
# Unnamed: 0            178
# Hour                  178
# HR                    232
# O2Sat                  74
# Temp                   84
# SBP                   387
# MAP                   482
# DBP                   205
# Resp                  121
# EtCO2                  67
# BaseExcess             63
# HCO3                   45
# FiO2                   11
# pH                      8
# PaCO2                 130
# SaO2                  120
# AST                   189
# BUN                   107
# Alkalinephos          167
# Calcium                71
# Chloride               50
# Creatinine             95
# Bilirubin_direct       17
# Glucose               372
# Lactate               101
# Magnesium              37
# Phosphate              86
# Potassium              56
# Bilirubin_total        64
# TroponinI              62
# Hct                   282
# Hgb                   113
# PTT                   415
# WBC                   266
# Fibrinogen            155
# Platelets             408
# Age                   715
# Gender                  2
# Unit1                   2
# Unit2                   2
# HospAdmTime          3301
# ICULOS                186
# SepsisLabel             2
# Patient_ID          27101
# dtype: int64
#
# Percentage of Unique Values:
# Unnamed: 0            0.656802
# Hour                  0.656802
# HR                    0.856057
# O2Sat                 0.273053
# Temp                  0.309952
# SBP                   1.427992
# MAP                   1.778532
# DBP                   0.756430
# Resp                  0.446478
# EtCO2                 0.247223
# BaseExcess            0.232464
# HCO3                  0.166046
# FiO2                  0.040589
# pH                    0.029519
# PaCO2                 0.479687
# SaO2                  0.442788
# AST                   0.697391
# BUN                   0.394819
# Alkalinephos          0.616213
# Calcium               0.261983
# Chloride              0.184495
# Creatinine            0.350541
# Bilirubin_direct      0.062728
# Glucose               1.372643
# Lactate               0.372680
# Magnesium             0.136526
# Phosphate             0.317331
# Potassium             0.206634
# Bilirubin_total       0.236154
# TroponinI             0.228774
# Hct                   1.040552
# Hgb                   0.416959
# PTT                   1.531309
# WBC                   0.981514
# Fibrinogen            0.571935
# Platelets             1.505480
# Age                   2.638279
# Gender                0.007380
# Unit1                 0.007380
# Unit2                 0.007380
# HospAdmTime          12.180362
# ICULOS                0.686322
# SepsisLabel           0.007380
# Patient_ID          100.000000
# dtype: float64
#
# Ranges of Values:
#      Unnamed: 0   Hour     HR  O2Sat  Temp    SBP    MAP    DBP  Resp  EtCO2  \
# min         0.0    0.0   20.0   22.0  30.2   28.0   20.0   22.0   1.0   10.0
# max       329.0  329.0  167.0  100.0  41.8  274.0  298.0  166.0  97.0   79.0
#
#      ...  Fibrinogen  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  \
# min  ...        59.0        7.0   15.0     0.0    0.0    0.0      -5366.9
# max  ...       816.0     1092.0  100.0     1.0    1.0    1.0         24.0
#
#      ICULOS  SepsisLabel  Patient_ID
# min     1.0          0.0         1.0
# max   333.0          1.0    119998.0
#
# [2 rows x 44 columns]

# %%
import pandas as pd

# Load the dataset 
df = pd.read_csv("Sepsis.csv")

# Calculate the mean values for the columns with missing data
mean_temp = df['Temp'].mean()
mean_sbp = df['SBP'].mean()
mean_dbp = df['DBP'].mean()
mean_resp = df['Resp'].mean()
mean_o2sat = df['O2Sat'].mean()
mean_map = df['MAP'].mean()
mean_hr = df['HR'].mean()

# Fill in missing values with the corresponding mean values
df['Temp'].fillna(mean_temp, inplace=True)
df['SBP'].fillna(mean_sbp, inplace=True)
df['DBP'].fillna(mean_dbp, inplace=True)
df['Resp'].fillna(mean_resp, inplace=True)
df['O2Sat'].fillna(mean_o2sat, inplace=True)
df['MAP'].fillna(mean_map, inplace=True)
df['HR'].fillna(mean_hr, inplace=True)

# Round all numbers to one decimal place in the entire DataFrame
df = df.round(1)

# Save the updated dataset to a new CSV file
df.to_csv("filled_patient_data.csv", index=False)

# %%
import pandas as pd
import random

# Load the filled dataset into a DataFrame
df = pd.read_csv("filled_patient_data.csv")

# Get a list of unique PatientIDs
unique_patient_ids = df['Patient_ID'].unique()

# Create a new DataFrame to store the randomly selected rows
random_selected_df = pd.DataFrame(columns=df.columns)

# Randomly select one row for each unique PatientID
for patient_id in unique_patient_ids:
    patient_rows = df[df['Patient_ID'] == patient_id]
    random_row = patient_rows.sample(n=1, random_state=random.seed())
    random_selected_df = pd.concat([random_selected_df, random_row])

# Save the dataset with one unique PatientID per row
random_selected_df.to_csv("unique_patient_data.csv", index=False)

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv("Sepsis.csv")

# Check if the 'PatientID' column exists in the DataFrame
if 'PatientID' in df.columns:
    # Check for null values
    if df.isnull().values.any():
        # Calculate the mean values for the columns with missing data
        mean_values = df.mean()

        # Fill in missing values with the corresponding mean values
        df.fillna(mean_values, inplace=True)

    # Round all numbers to one decimal place in the entire DataFrame
    df = df.round(1)

    # Example of cleaning a specific column using str.contains() and str.extract()
    # Let's say you want to clean the 'PatientID' column to extract only numeric values
    df['PatientID'] = df['PatientID'].str.extract(r'(\d+)')

    # Save the updated dataset to a new CSV file
    df.to_csv("filled_and_cleaned_patient_data.csv", index=False)
else:
    print("The 'PatientID' column does not exist in the DataFrame.")
# Out:
# The 'PatientID' column does not exist in the DataFrame.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt



# Define features and target variable
features = ['HR', 'MAP', 'SBP', 'DBP', 'O2Sat', 'Temp', 'Resp']
target = 'SepsisLabel' 
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Initialize the KNN model with a specified number of neighbors (e.g., n_neighbors=5)
knn_model = KNeighborsClassifier(n_neighbors=5)

# Train the model
knn_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = knn_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Classification Report:\n", classification_rep)

# Calculate ROC-AUC
y_prob = knn_model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)

# Create ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print AUC
print("AUC:", roc_auc)
# Out:
# C:\Users\nicho\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# Accuracy: 0.9801254082922061
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    205582
#            1       0.21      0.00      0.01      4133
#
#     accuracy                           0.98    209715
#    macro avg       0.60      0.50      0.50    209715
# weighted avg       0.97      0.98      0.97    209715
# AUC: 0.5411412487161521

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

df = pd.read_csv('unique_patient_data.csv')

# Define features and target variable
features = ['HR', 'MAP', 'SBP', 'DBP', 'O2Sat', 'Temp', 'Resp']
target = 'SepsisLabel' 
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Standardize features (optional but recommended for SVM)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Initialize the SVM model
svm_model = SVC(kernel='linear', C=1.0, random_state=42)

# Train the model
svm_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = svm_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)



print("Accuracy:", accuracy)
print("Confusion Matrix:\n", confusion)
print("Classification Report:\n", classification_rep)

# Predict probabilities for the positive class (class 1)
y_prob = svm_model.decision_function(X_test)

# Calculate ROC-AUC
roc_auc = roc_auc_score(y_test, y_prob)

# Create ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print AUC
print("AUC:", roc_auc)
# Out:
# C:\Users\nicho\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nicho\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nicho\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.9680870688064933
# Confusion Matrix:
#  [[5248    0]
#  [ 173    0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5248
#            1       0.00      0.00      0.00       173
#
#     accuracy                           0.97      5421
#    macro avg       0.48      0.50      0.49      5421
# weighted avg       0.94      0.97      0.95      5421
# AUC: 0.5193775993937685

# %%
import scipy.stats as stats

# Lists of performance metrics for each model
svm_metrics = [0.55]  
logistic_metrics = [0.61]  
knn_metrics = [0.54]  

# Perform the Wilcoxon signed-rank test for SVM vs. Logistic Regression
svm_vs_logistic, p_value_sl = stats.wilcoxon(svm_metrics, logistic_metrics)

# Perform the Wilcoxon signed-rank test for SVM vs. KNN
svm_vs_knn, p_value_sk = stats.wilcoxon(svm_metrics, knn_metrics)

# Perform the Wilcoxon signed-rank test for Logistic Regression vs. KNN
logistic_vs_knn, p_value_lk = stats.wilcoxon(logistic_metrics, knn_metrics)

# Set the significance level (alpha)
alpha = 0.05

# Compare SVM vs. Logistic Regression
if p_value_sl < alpha:
    print("SVM and Logistic Regression have significantly different performance.")
else:
    print("SVM and Logistic Regression do not have significantly different performance.")

# Compare SVM vs. KNN
if p_value_sk < alpha:
    print("SVM and KNN have significantly different performance.")
else:
    print("SVM and KNN do not have significantly different performance.")

# Compare Logistic Regression vs. KNN
if p_value_lk < alpha:
    print("Logistic Regression and KNN have significantly different performance.")
else:
    print("Logistic Regression and KNN do not have significantly different performance.")
# Out:
# SVM and Logistic Regression do not have significantly different performance.
# SVM and KNN do not have significantly different performance.
# Logistic Regression and KNN do not have significantly different performance.

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# Load your dataset (assuming you have a DataFrame named 'df')
# Preprocess your data as needed (e.g., handle missing values)

# Define features and target variable
features = ['HR', 'MAP', 'SBP', 'DBP', 'O2Sat', 'Temp', 'Resp']
target = 'SepsisLabel' 

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Initialize and train the KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)  
knn_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = knn_model.predict(X_test)

# Evaluate the KNN model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print("KNN Accuracy:", accuracy)
print("KNN Classification Report:\n", classification_rep)

# Visualize the KNN predictions using a scatter plot (e.g., HR vs. MAP)
plt.figure(figsize=(8, 6))
plt.scatter(X_test['HR'], X_test['MAP'], c=y_pred, cmap='viridis')
plt.xlabel('Heart Rate (HR)')
plt.ylabel('Mean Arterial Pressure (MAP)')
plt.title('KNN Predictions for Sepsis')
plt.colorbar(label='Prediction (0: Normal / 1: Sepsis)')
plt.show()
# Out:
# KNN Accuracy: 0.967718133185759
# KNN Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5248
#            1       0.00      0.00      0.00       173
#
#     accuracy                           0.97      5421
#    macro avg       0.48      0.50      0.49      5421
# weighted avg       0.94      0.97      0.95      5421

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# Load your dataset (assuming you have a DataFrame named 'df')
# Preprocess your data as needed (e.g., handle missing values)

# Define features and target variable
features = ['SBP', 'DBP', 'O2Sat', 'Temp', 'Resp']  
target = 'SepsisLabel' 

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Initialize and train the KNN model
knn_model = KNeighborsClassifier(n_neighbors=5) 
knn_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = knn_model.predict(X_test)

# Evaluate the KNN model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print("KNN Accuracy:", accuracy)
print("KNN Classification Report:\n", classification_rep)

# Visualize the KNN predictions using a scatter plot (e.g., SBP vs. DBP)
plt.figure(figsize=(8, 6))
plt.scatter(X_test['SBP'], X_test['DBP'], c=y_pred, cmap='viridis')
plt.xlabel('Systolic Blood Pressure (SBP)')
plt.ylabel('Diastolic Blood Pressure (DBP)')
plt.title('KNN Predictions for Sepsis')
plt.colorbar(label='Prediction (0: Normal / 1: Sepsis)')
plt.show()
# Out:
# KNN Accuracy: 0.9673491975650249
# KNN Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5248
#            1       0.17      0.01      0.01       173
#
#     accuracy                           0.97      5421
#    macro avg       0.57      0.50      0.50      5421
# weighted avg       0.94      0.97      0.95      5421

# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.DataFrame(np.random.rand(100, 5), columns=["a", "b", "c", "d", "e"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from ydata_profiling import ProfileReport
#       5 df = pd.DataFrame(np.random.rand(100, 5), columns=["a", "b", "c", "d", "e"])
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 profile = ProfileReport(df, title="Pandas Profiling Report")
#
# NameError: name 'ProfileReport' is not defined

# %%
profile.to_widgets()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 profile.to_widgets()
#
# NameError: name 'profile' is not defined

# %%
profile.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 profile.to_notebook_iframe()
#
# NameError: name 'profile' is not defined

# %%
profile.to_file("your_report.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 profile.to_file("your_report.html")
#
# NameError: name 'profile' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset into a DataFrame 
df = pd.read_csv("unique_patient_data.csv")

# Subset the DataFrame to include only the specified features
features = ['HR', 'MAP', 'SBP', 'DBP', 'O2Sat', 'Temp', 'Resp']
subset_df = df[features]

# Summary statistics
summary_stats = subset_df.describe()

# Histograms for each feature
plt.figure(figsize=(12, 8))
for i, feature in enumerate(features, start=1):
    plt.subplot(3, 3, i)
    sns.histplot(subset_df[feature], bins=20, kde=True)
    plt.title(f'{feature} Distribution')
    plt.xlabel(feature)

plt.tight_layout()
plt.show()

# Box plots for each feature
plt.figure(figsize=(12, 8))
for i, feature in enumerate(features, start=1):
    plt.subplot(3, 3, i)
    sns.boxplot(y=subset_df[feature])
    plt.title(f'{feature} Box Plot')
    plt.ylabel(feature)

plt.tight_layout()
plt.show()

# Pairplot to visualize pairwise relationships
sns.pairplot(subset_df, diag_kind='kde')
plt.show()

# Correlation heatmap
correlation_matrix = subset_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# Check for categorical data
categorical_columns = df.select_dtypes(include=['object']).columns
print("Categorical columns:", categorical_columns)

# Scale the features
scaler = preprocessing.StandardScaler()
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)

# Split the dataset into training and testing datasets
X_train, X_test = train_test_split(scaled_df, test_size=0.2, random_state=42)
# Out:
# Categorical columns: Index([], dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = pd.read_csv("unique_patient_data.csv")

# Split the dataset into features (X) and target variable (y)
X = df.drop(columns=['SepsisLabel'])
y = df['SepsisLabel']

# One-hot encode categorical variables if any
X_encoded = pd.get_dummies(X)

# Standardize the magnitude of numeric features using StandardScaler
scaler = StandardScaler()
scaled_features = scaler.fit_transform(X_encoded)
scaled_df = pd.DataFrame(scaled_features, columns=X_encoded.columns)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(scaled_df, y, test_size=0.2, random_state=42)

# You can use X_train, X_test, y_train, and y_test for training and testing your models, respectively

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = pd.read_csv("unique_patient_data.csv")

# Check if 'Outcome' column exists in the DataFrame
if 'Outcome' not in df.columns:
    print("Error: 'Outcome' column not found in the dataset.")
else:
    # Preprocessing: Drop unnecessary columns and handle missing values
    # (You may need to perform more preprocessing based on your dataset)
    df.drop(columns=['Patient_ID'], inplace=True)  # Drop Patient_ID column if it's unnecessary

    # Handling missing values: For simplicity, let's fill missing values with mean for numeric columns
    df.fillna(df.mean(), inplace=True)

    # Splitting the data into features and target variable
    X = df.drop(columns=['Outcome'])  # Features
    y = df['Outcome']  # Target variable

    # Standardize the features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
# Out:
# Error: 'Outcome' column not found in the dataset.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier

# Load the dataset
df = pd.read_csv("unique_patient_data.csv")

# Preprocessing: Drop unnecessary columns and handle missing values
# (You may need to perform more preprocessing based on your dataset)
df.drop(columns=['Patient_ID', 'Outcome'], inplace=True)  # Drop Patient_ID and Outcome columns if unnecessary

# Handling missing values: For simplicity, let's fill missing values with mean for numeric columns
df.fillna(df.mean(), inplace=True)

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# Split the data into training and testing sets (Note: No y variable for unsupervised learning)
X_train, X_test = train_test_split(X_scaled, test_size=0.3, random_state=42)

# Create XGBoost model (unsupervised learning)
xgb_model = XGBClassifier(objective='reg:squarederror')  # Set objective to 'reg:squarederror' for unsupervised learning

# Fit the model
xgb_model.fit(X_train)

# Perform anomaly detection or clustering with the trained model as needed
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 11
#       7 df = pd.read_csv("unique_patient_data.csv")
#       9 # Preprocessing: Drop unnecessary columns and handle missing values
#      10 # (You may need to perform more preprocessing based on your dataset)
# ---> 11 df.drop(columns=['Patient_ID', 'Outcome'], inplace=True)  # Drop Patient_ID and Outcome columns if unnecessary
#      13 # Handling missing values: For simplicity, let's fill missing values with mean for numeric columns
#      14 df.fillna(df.mean(), inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Outcome'] not found in axis"

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('unique_patient_data.csv')

# Define features and target variable
features = ['HR', 'MAP', 'SBP', 'DBP', 'O2Sat', 'Temp', 'Resp']
target = 'SepsisLabel'

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Standardize features (optional but recommended for some models like KNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train models
models = {
    'XGBoost': XGBClassifier(),
    'KNN': KNeighborsClassifier(),
    'DecisionTree': DecisionTreeClassifier()
}

for model_name, model in models.items():
    # Train the model
    model.fit(X_train_scaled, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test_scaled)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)
    classification_rep = classification_report(y_test, y_pred)

    print(f"Results for {model_name}:")
    print("Accuracy:", accuracy)
    print("Confusion Matrix:\n", confusion)
    print("Classification Report:\n", classification_rep)

    # If the model supports probability estimates, calculate ROC-AUC
    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X_test_scaled)[:, 1]
        roc_auc = roc_auc_score(y_test, y_prob)

        # Create ROC curve
        fpr, tpr, thresholds = roc_curve(y_test, y_prob)

        # Plot ROC curve
        plt.figure(figsize=(8, 6))
        plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'Receiver Operating Characteristic (ROC) Curve for {model_name}')
        plt.legend()
        plt.show()

        # Print AUC
        print("AUC:", roc_auc)
    print("\n")
# Out:
# Results for XGBoost:
# Accuracy: 0.9671647297546578
# Confusion Matrix:
#  [[5243    5]
#  [ 173    0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5248
#            1       0.00      0.00      0.00       173
#
#     accuracy                           0.97      5421
#    macro avg       0.48      0.50      0.49      5421
# weighted avg       0.94      0.97      0.95      5421
# AUC: 0.5782571725645003
#
#
# Results for KNN:
# Accuracy: 0.9679026009961261
# Confusion Matrix:
#  [[5247    1]
#  [ 173    0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5248
#            1       0.00      0.00      0.00       173
#
#     accuracy                           0.97      5421
#    macro avg       0.48      0.50      0.49      5421
# weighted avg       0.94      0.97      0.95      5421
# AUC: 0.5201585189623572
#
#
# Results for DecisionTree:
# Accuracy: 0.9297177642501383
# Confusion Matrix:
#  [[5032  216]
#  [ 165    8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      5248
#            1       0.04      0.05      0.04       173
#
#     accuracy                           0.93      5421
#    macro avg       0.50      0.50      0.50      5421
# weighted avg       0.94      0.93      0.93      5421
# AUC: 0.49831259692654734
